# %% [markdown]
# Column name Abbreviation -  meaning

# %% [markdown]
#  Abbreviation    | Full Form                                 |
# |:---------------|:------------------------------------------|
# | FAVC           | Frequent consumption of high caloric food |
# | FCVC           | Frequency of consumption of vegetables    |
# | NCP            | Number of main meals                      |
# | CAEC           | Consumption of food between meals         |
# | CH20           | Consumption of water daily                |
# | CALC           | Consumption of alcohol                    |
# | SCC            | Calories consumption monitoring           |
# | FAF            | Physical activity frequency               |
# | TUE            | Time using technology devices             |
# | MTRANS         | Transportation used

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
from catboost import CatBoostClassifier
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from catboost import CatBoostClassifier
#
# File ~/miniconda3/envs/data/lib/python3.11/site-packages/catboost/__init__.py:1
# ----> 1 from .core import (
#       2     FeaturesData, EFstrType, EShapCalcType, EFeaturesSelectionAlgorithm, EFeaturesSelectionGrouping,
#       3     Pool, CatBoost, CatBoostClassifier, CatBoostRegressor, CatBoostRanker, CatBoostError, cv, sample_gaussian_process, train,
#       4     sum_models, _have_equal_features, to_regressor, to_classifier, to_ranker, MultiRegressionCustomMetric,
#       5     MultiRegressionCustomObjective, MultiTargetCustomMetric, MultiTargetCustomObjective
#       6 )  # noqa
#       7 from .version import VERSION as __version__  # noqa
#       8 __all__ = [
#       9     'FeaturesData', 'EFstrType', 'EShapCalcType', 'EFeaturesSelectionAlgorithm', 'EFeaturesSelectionGrouping',
#      10     'Pool', 'CatBoost', 'CatBoostClassifier', 'CatBoostRegressor', 'CatBoostRanker', 'CatboostError',
#    (...)
#      13     'MultiTargetCustomMetric', 'MultiTargetCustomObjective'
#      14 ]
#
# File ~/miniconda3/envs/data/lib/python3.11/site-packages/catboost/core.py:45
#      40         pass
#      42 import scipy.sparse
# ---> 45 from .plot_helpers import save_plot_file, try_plot_offline, OfflineMetricVisualizer
#      46 from . import _catboost
#      47 from .metrics import BuiltinMetric
#
# File ~/miniconda3/envs/data/lib/python3.11/site-packages/catboost/plot_helpers.py:5
#       2 import os
#       3 import warnings
# ----> 5 from . import _catboost
#       6 fspath = _catboost.fspath
#       9 def try_plot_offline(figs):
#
# File _catboost.pyx:1, in init _catboost()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
#Seaborn settings for visualizations!
rc = {
    "axes.facecolor": "#f7f9fc",
    "figure.facecolor": "#f7f9fc",
    "axes.edgecolor": "#000000",
    "grid.color": "#EBEBE7",
    "font.family": "serif",
    "axes.labelcolor": "#000000",
    "xtick.color": "#000000",
    "ytick.color": "#000000",
    "grid.alpha": 0.4
}

default_palette = 'YlOrRd'

sns.set(rc=rc)
pd.set_option('display.max_columns',35)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
original = pd.read_csv('ObesityDataSet.csv')

# %%
print(f'The Train dataset has {df_train.shape[0]} rows and {df_train.shape[1]} columns')
print(f'The Test dataset has {df_test.shape[0]} rows and {df_test.shape[1]} columns')
# Out:
# The Train dataset has 20758 rows and 18 columns
# The Test dataset has 13840 rows and 17 columns

# %%
df_train.describe().to_csv('output.csv', index=False)

# %%
display('Train:',df_train.head())
display('Test:',df_test.head())
# Out:
# 'Train:'
#    id  Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   0    Male 24.44    1.70   81.67                            yes  yes  2.00
# 1   1  Female 18.00    1.56   57.00                            yes  yes  2.00
# 2   2  Female 18.00    1.71   50.17                            yes  yes  1.88
# 3   3  Female 20.95    1.71  131.27                            yes  yes  3.00
# 4   4    Male 31.64    1.91   93.80                            yes  yes  2.68
#
#    NCP        CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 0 2.98   Sometimes    no  2.76  no 0.00 0.98  Sometimes
# 1 3.00  Frequently    no  2.00  no 1.00 1.00         no
# 2 1.41   Sometimes    no  1.91  no 0.87 1.67         no
# 3 3.00   Sometimes    no  1.67  no 1.47 0.78  Sometimes
# 4 1.97   Sometimes    no  1.98  no 1.97 0.93  Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation  Overweight_Level_II
# 1             Automobile        Normal_Weight
# 2  Public_Transportation  Insufficient_Weight
# 3  Public_Transportation     Obesity_Type_III
# 4  Public_Transportation  Overweight_Level_II
# 'Test:'
#       id  Gender   Age  Height  Weight family_history_with_overweight FAVC  \
# 0  20758    Male 26.90    1.85  120.64                            yes  yes
# 1  20759  Female 21.00    1.60   66.00                            yes  yes
# 2  20760  Female 26.00    1.64  111.60                            yes  yes
# 3  20761    Male 20.98    1.55  103.67                            yes  yes
# 4  20762  Female 26.00    1.63  104.84                            yes  yes
#
#    FCVC  NCP       CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 0  2.94 3.00  Sometimes    no  2.83  no 0.86 0.00  Sometimes
# 1  2.00 1.00  Sometimes    no  3.00  no 1.00 0.00  Sometimes
# 2  3.00 3.00  Sometimes    no  2.62  no 0.00 0.25  Sometimes
# 3  2.00 2.98  Sometimes    no  2.79  no 0.09 0.00  Sometimes
# 4  3.00 3.00  Sometimes    no  2.65  no 0.00 0.74  Sometimes
#
#                   MTRANS
# 0  Public_Transportation
# 1  Public_Transportation
# 2  Public_Transportation
# 3  Public_Transportation
# 4  Public_Transportation

# %%
from utils import summary
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from utils import summary
#
# ImportError: cannot import name 'summary' from 'utils' (/Users/yzhang/b/p/predict-obesity/utils.py)

# %%
summary(df_train.drop(columns=["id"])).style.background_gradient()
# Out:
# <style type="text/css">
# #T_3fed1_row0_col1, #T_3fed1_row0_col2, #T_3fed1_row0_col3, #T_3fed1_row1_col1, #T_3fed1_row1_col2, #T_3fed1_row2_col1, #T_3fed1_row2_col2, #T_3fed1_row3_col1, #T_3fed1_row3_col2, #T_3fed1_row4_col1, #T_3fed1_row4_col2, #T_3fed1_row4_col3, #T_3fed1_row5_col1, #T_3fed1_row5_col2, #T_3fed1_row5_col3, #T_3fed1_row6_col1, #T_3fed1_row6_col2, #T_3fed1_row7_col1, #T_3fed1_row7_col2, #T_3fed1_row8_col1, #T_3fed1_row8_col2, #T_3fed1_row8_col3, #T_3fed1_row9_col1, #T_3fed1_row9_col2, #T_3fed1_row9_col3, #T_3fed1_row10_col1, #T_3fed1_row10_col2, #T_3fed1_row11_col1, #T_3fed1_row11_col2, #T_3fed1_row11_col3, #T_3fed1_row12_col1, #T_3fed1_row12_col2, #T_3fed1_row13_col1, #T_3fed1_row13_col2, #T_3fed1_row14_col1, #T_3fed1_row14_col2, #T_3fed1_row14_col3, #T_3fed1_row15_col1, #T_3fed1_row15_col2, #T_3fed1_row15_col3, #T_3fed1_row16_col1, #T_3fed1_row16_col2, #T_3fed1_row16_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3fed1_row1_col3 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_3fed1_row2_col3 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_3fed1_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3fed1_row6_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_3fed1_row7_col3 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_3fed1_row10_col3 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_3fed1_row12_col3 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_3fed1_row13_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3fed1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fed1_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_3fed1_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_3fed1_level0_col2" class="col_heading level0 col2" >Duplicate</th>
#       <th id="T_3fed1_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_3fed1_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_3fed1_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_3fed1_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_3fed1_level0_col7" class="col_heading level0 col7" >std dev</th>
#       <th id="T_3fed1_level0_col8" class="col_heading level0 col8" >top value</th>
#       <th id="T_3fed1_level0_col9" class="col_heading level0 col9" >Freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fed1_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_3fed1_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_3fed1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3fed1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3fed1_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_3fed1_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_3fed1_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_3fed1_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_3fed1_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_3fed1_row0_col8" class="data row0 col8" >Female</td>
#       <td id="T_3fed1_row0_col9" class="data row0 col9" >10422</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_3fed1_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_3fed1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_3fed1_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_3fed1_row1_col3" class="data row1 col3" >1703</td>
#       <td id="T_3fed1_row1_col4" class="data row1 col4" >14.000000</td>
#       <td id="T_3fed1_row1_col5" class="data row1 col5" >61.000000</td>
#       <td id="T_3fed1_row1_col6" class="data row1 col6" >23.841804</td>
#       <td id="T_3fed1_row1_col7" class="data row1 col7" >5.688072</td>
#       <td id="T_3fed1_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_3fed1_row1_col9" class="data row1 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row2" class="row_heading level0 row2" >Height</th>
#       <td id="T_3fed1_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_3fed1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3fed1_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_3fed1_row2_col3" class="data row2 col3" >1833</td>
#       <td id="T_3fed1_row2_col4" class="data row2 col4" >1.450000</td>
#       <td id="T_3fed1_row2_col5" class="data row2 col5" >1.975663</td>
#       <td id="T_3fed1_row2_col6" class="data row2 col6" >1.700245</td>
#       <td id="T_3fed1_row2_col7" class="data row2 col7" >0.087312</td>
#       <td id="T_3fed1_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_3fed1_row2_col9" class="data row2 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row3" class="row_heading level0 row3" >Weight</th>
#       <td id="T_3fed1_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_3fed1_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_3fed1_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_3fed1_row3_col3" class="data row3 col3" >1979</td>
#       <td id="T_3fed1_row3_col4" class="data row3 col4" >39.000000</td>
#       <td id="T_3fed1_row3_col5" class="data row3 col5" >165.057269</td>
#       <td id="T_3fed1_row3_col6" class="data row3 col6" >87.887768</td>
#       <td id="T_3fed1_row3_col7" class="data row3 col7" >26.379443</td>
#       <td id="T_3fed1_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_3fed1_row3_col9" class="data row3 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row4" class="row_heading level0 row4" >family_history_with_overweight</th>
#       <td id="T_3fed1_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_3fed1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_3fed1_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_3fed1_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_3fed1_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_3fed1_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_3fed1_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_3fed1_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_3fed1_row4_col8" class="data row4 col8" >yes</td>
#       <td id="T_3fed1_row4_col9" class="data row4 col9" >17014</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row5" class="row_heading level0 row5" >FAVC</th>
#       <td id="T_3fed1_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_3fed1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_3fed1_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_3fed1_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_3fed1_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_3fed1_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_3fed1_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_3fed1_row5_col7" class="data row5 col7" >nan</td>
#       <td id="T_3fed1_row5_col8" class="data row5 col8" >yes</td>
#       <td id="T_3fed1_row5_col9" class="data row5 col9" >18982</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row6" class="row_heading level0 row6" >FCVC</th>
#       <td id="T_3fed1_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_3fed1_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_3fed1_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_3fed1_row6_col3" class="data row6 col3" >934</td>
#       <td id="T_3fed1_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_3fed1_row6_col5" class="data row6 col5" >3.000000</td>
#       <td id="T_3fed1_row6_col6" class="data row6 col6" >2.445908</td>
#       <td id="T_3fed1_row6_col7" class="data row6 col7" >0.533218</td>
#       <td id="T_3fed1_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_3fed1_row6_col9" class="data row6 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3fed1_level0_row7" class="row_heading level0 row7" >NCP</th>
#       <td id="T_3fed1_row7_col0" class="data row7 co

# %% [markdown]
# # Exploratory Data Analysis

# %%
from utils import describeColumn

# %%
describeColumn('NObeyesdad', df_train, 'Obesity Type')

# %%
describeColumn('Gender', df_train, 'Gender')

# %%
describeColumn("family_history_with_overweight", df_train)

# %%
describeColumn("FAVC", df_train, 'Frequent consumption of high caloric food')

# %%
describeColumn("CAEC", df_train, 'Consumption of food between meals')

# %%
describeColumn("SMOKE", df_train)

# %%
describeColumn("SMOKE", df_train, 'Calories consumption monitoring')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 describeColumn("SMOKE", df_train, '	Calories consumption monitoring')
#
# TypeError: describeColumn() takes 2 positional arguments but 3 were given

# %%
describeColumn("CALC", df_train, 'Consumption of alcohol')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 describeColumn("CALC", df_train, 'Consumption of alcohol')
#
# TypeError: describeColumn() takes 2 positional arguments but 3 were given

# %%
describeColumn("MTRANS", df_train, 'Transportation used')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 describeColumn("MTRANS", df_train, 'Transportation used')
#
# TypeError: describeColumn() takes 2 positional arguments but 3 were given

# %%
from utils import dist
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 from utils import dist
#
# ImportError: cannot import name 'dist' from 'utils' (/Users/yzhang/b/p/predict-obesity/utils.py)

# %%
numeric_columns = df_train.select_dtypes(include=['float64', 'int64']).drop(columns=['id'], axis=1)

# %%
dist(train_dataset=df_train, columns_list=numeric_columns.columns, rows=2, cols=4,original_dataset=original)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 dist(train_dataset=df_train, columns_list=numeric_columns.columns, rows=2, cols=4,original_dataset=original)
#
# NameError: name 'dist' is not defined
